# %%
import numpy as np
import pandas as pd
import os
import pathlib
import shutil
import matplotlib.pyplot as plt
import seaborn as snb

# %% [markdown]
# # 1.Linear Regression and Nearest Neighbors

# %% [markdown]
# ## 1.1 Advertising Dataset
#
# The following dataset contains the sales information for a product in 200 different markets and displayes the advertising budget for the product in 3 different media types.

# %%
advertising = pd.read_csv("C:\\Users\\Mohammed Ali\\Documents\\Documents-Suhaib\\ISLRV2\\data\\ALL CSV FILES - 2nd Edition\\Advertising.csv", index_col=0)

snb.set_palette("pastel")

# %%
advertising.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
fix, ax = plt.subplots(1, 3, figsize=(16, 8))

snb.scatterplot(x="TV", y="sales", data=advertising, ax=ax[0])
snb.scatterplot(x="radio", y="sales", data=advertising, ax=ax[1])
snb.scatterplot(x="newspaper", y="sales", data=advertising, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='sales'>

# %% [markdown]
# # 2.Exercises

# %% [markdown]
# ### 2.6 Calculate the euclidean distance between the point (0,0,0) and the training data points.

# %%
X = np.array([
    [0,2,0],
    [0,3,0],
    [0, 1, 3],
    [0, 1, 2],
    [-1, 0, 1],
    [1,1,1]
])

x_new = np.array([0, 0, 0])

# %%
x_dff = X - x_new

# %%
np.linalg.norm(x_dff, axis=1)
# Out:
# array([2.        , 3.        , 3.16227766, 2.23606798, 1.41421356,
#        1.73205081])
